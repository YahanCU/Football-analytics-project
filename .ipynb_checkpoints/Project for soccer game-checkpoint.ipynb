# %% [markdown]
# 'Project code for tools'

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('CompleteDataset.csv')
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### comparing player

# %%
# draft

df1 = df[['Name','Age','Potential']].head(10)
y = df1['Age']
x = df1['Name']
plt.figure(figsize=(12,10))
plt.barh(x, y)
plt.barh(x, -y)
plt.xticks(())
plt.xlabel(' %s                                %s'%('name1','name2'),labelpad = 15, fontsize = 'xx-large')
for x, y in zip(x, y):
#     ha: horizontal alignmen
#     va: vertical alignment
    plt.text(y, x, '%d' % y, ha='left', va = 'center',fontsize = 'large')
    plt.text(-y, x, '%d' % -y, ha='right',va = 'center',fontsize = 'large')
